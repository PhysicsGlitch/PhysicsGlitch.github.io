# %%
# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata
from config import CHI_API_KEY

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofchicago.org", CHI_API_KEY)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("85ca-t3if", limit=500000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_df.head()
# Out:
#                                      crash_record_id               crash_date  \
# 0  1d0b6295ed8ecc52585b2c4825eee723fd51ca4fc1c0bc...  2020-10-10T01:23:00.000
# 1  1791a96fc83772d013a94af00f6315603b4337bdd1204c...  2020-10-10T01:15:00.000
# 2  3f0ea94406089fb36fe862cdd019d9f217af7331faab61...  2020-10-10T00:35:00.000
# 3  ea3a052cacc9082647e8cf74049eb0fe4e8a70af10c397...  2020-10-09T23:40:00.000
# 4  96bf92e29f4efdc665fa74bcc8db3cb7bcac076cc1d6be...  2020-10-09T23:10:00.000
#
#   posted_speed_limit traffic_control_device      device_condition  \
# 0                 30         TRAFFIC SIGNAL  FUNCTIONING PROPERLY
# 1                 30         TRAFFIC SIGNAL  FUNCTIONING PROPERLY
# 2                 30         TRAFFIC SIGNAL               UNKNOWN
# 3                 25            NO CONTROLS           NO CONTROLS
# 4                 30         TRAFFIC SIGNAL  FUNCTIONING PROPERLY
#
#   weather_condition      lighting_condition          first_crash_type  \
# 0             CLEAR  DARKNESS, LIGHTED ROAD                     ANGLE
# 1           UNKNOWN  DARKNESS, LIGHTED ROAD                  REAR END
# 2             CLEAR  DARKNESS, LIGHTED ROAD  SIDESWIPE SAME DIRECTION
# 3             CLEAR  DARKNESS, LIGHTED ROAD      PARKED MOTOR VEHICLE
# 4             CLEAR  DARKNESS, LIGHTED ROAD  SIDESWIPE SAME DIRECTION
#
#                    trafficway_type           alignment  ... crash_date_est_i  \
# 0                   T-INTERSECTION  STRAIGHT AND LEVEL  ...              NaN
# 1                         FOUR WAY  STRAIGHT AND LEVEL  ...              NaN
# 2                         FOUR WAY  STRAIGHT AND LEVEL  ...              NaN
# 3                      NOT DIVIDED  STRAIGHT AND LEVEL  ...              NaN
# 4  DIVIDED - W/MEDIAN (NOT RAISED)  STRAIGHT AND LEVEL  ...              NaN
#
#   private_property_i photos_taken_i work_zone_i work_zone_type  \
# 0                NaN            NaN         NaN            NaN
# 1                NaN            NaN         NaN            NaN
# 2                NaN            NaN         NaN            NaN
# 3                NaN            NaN         NaN            NaN
# 4                NaN            NaN         NaN            NaN
#
#   statements_taken_i dooring_i workers_present_i rd_no lane_cnt
# 0                NaN       NaN               NaN   NaN      NaN
# 1                NaN       NaN               NaN   NaN      NaN
# 2                NaN       NaN               NaN   NaN      NaN
# 3                NaN       NaN               NaN   NaN      NaN
# 4                NaN       NaN               NaN   NaN      NaN
#
# [5 rows x 49 columns]

# %%
index = results_df.index
number_of_rows = len(index)
number_of_rows
# Out:
# 446285

# %%
# Saving Dataframe to File
results_df.to_json (r'accidents.json')

# %%
accidents = pd.read_json('accidents.json')

# %%
accidents.head()
# Out:
#                                      crash_record_id               crash_date  \
# 0  c14e9e633198e28603d183db9bf193816e209a31735d1d...  2020-10-09T01:46:00.000
# 1  24811236a6c419498e788ab30b775b2265d3392cc4929b...  2020-10-09T00:45:00.000
# 2  d3c28f5f148f794400b72553ba079d09b71f68a9022444...  2020-10-09T00:38:00.000
# 3  641ffa1f702d3a1d40881ca172efeab531e326129e5499...  2020-10-09T00:01:00.000
# 4  d06ea04e74036bea205125620281116257a92931e4a567...  2020-10-08T23:47:00.000
#
#    posted_speed_limit traffic_control_device      device_condition  \
# 0                  20            NO CONTROLS           NO CONTROLS
# 1                  35         TRAFFIC SIGNAL  FUNCTIONING PROPERLY
# 2                  30            NO CONTROLS           NO CONTROLS
# 3                  30            NO CONTROLS           NO CONTROLS
# 4                  30         TRAFFIC SIGNAL  FUNCTIONING PROPERLY
#
#   weather_condition      lighting_condition      first_crash_type  \
# 0             CLEAR  DARKNESS, LIGHTED ROAD  PARKED MOTOR VEHICLE
# 1             CLEAR  DARKNESS, LIGHTED ROAD               TURNING
# 2             CLEAR  DARKNESS, LIGHTED ROAD  PARKED MOTOR VEHICLE
# 3             CLEAR  DARKNESS, LIGHTED ROAD  PARKED MOTOR VEHICLE
# 4             CLEAR  DARKNESS, LIGHTED ROAD                 ANGLE
#
#                    trafficway_type           alignment  ... crash_date_est_i  \
# 0                          ONE-WAY  STRAIGHT AND LEVEL  ...             None
# 1                         FOUR WAY  STRAIGHT AND LEVEL  ...             None
# 2                          ONE-WAY  STRAIGHT AND LEVEL  ...             None
# 3                          ONE-WAY  STRAIGHT AND LEVEL  ...             None
# 4  DIVIDED - W/MEDIAN (NOT RAISED)  STRAIGHT AND LEVEL  ...             None
#
#   private_property_i statements_taken_i dooring_i photos_taken_i work_zone_i  \
# 0               None               None      None           None        None
# 1               None               None      None           None        None
# 2               None               None      None           None        None
# 3               None               None      None           None        None
# 4               None               None      None           None        None
#
#   work_zone_type workers_present_i rd_no  lane_cnt
# 0           None              None  None       NaN
# 1           None              None  None       NaN
# 2           None              None  None       NaN
# 3           None              None  None       NaN
# 4           None              None  None       NaN
#
# [5 rows x 49 columns]
